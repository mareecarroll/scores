# %% [markdown]
# ## This notebook exists soley for the purpose of creating images for the tutorial gallery (when it does not automatically work directly from the relevant notebook)

# %% [markdown]
# [Block_Bootstrapping.ipynb](../Block_Bootstrapping.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Block Bootstrapping](block_bootstrapping_thumbnail.png)

# %% [markdown]
# [Isotonic_Regression_And_Reliability_Diagrams.ipynb](../Isotonic_Regression_And_Reliability_Diagrams.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Isotonic Regression and Reliability Diagrams](isotonic_regression_thumbnail.png)

# %% [markdown]
# [Binary_Contingency_Scores.ipynb](../Binary_Contingency_Scores.ipynb) tutorial gallery thumbnail(below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Binary Contingency Scores](binary_contingency_thumbnail.png)

# %% [markdown]
# [Q-Q_plots.ipynb](../Q-Q_plots.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Q-Q plots](qq_thumbnail.png)

# %% [markdown]
# [Angular_data.ipynb](../Angular_data.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Angular Data](angular_data_thumbnail.png)

# %% [markdown]
# [Dimension_Handling.ipynb](../Dimension_Handling.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Dimension Handling](dimension_handling_thumbnail.png)

# %% [markdown]
# [NSE.ipynb](../NSE.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on the Nash Sutcliffe Efficiency (score)](NSE_thumbnail.png)

# %% [markdown]
# [Quantile_Loss.ipynb](../Quantile_Loss.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Quantile Loss](quantile_loss_thumbnail.png)

# %% [markdown]
# [Threshold_Weighted_Scores.ipynb](../Threshold_Weighted_Scores.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Threshold Weighted Scores](threshold_weighted_scores_thumbnail.png)

# %% [markdown]
# [Threshold_Weighted_CRPS_for_Ensembles.ipynb](../Threshold_Weighted_CRPS_for_Ensembles.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Threshold-weighted Continuous Ranked Probability Score (CRPS)](twCRPS_for_ensembles_thumbnail.png)

# %% [markdown]
# [Brier_Score.ipynb](../Brier_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Brier Score](brier_thumbnail.png)

# %% [markdown]
# [Quantile_Interval_And_Interval_Score.ipynb](../Quantile_Interval_And_Interval_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Quantile Interval Score and Interval Score](quantile_interval_score_and_interval_score_thumbnail.png)

# %% [markdown]
# [Fractions_Skill_Score.ipynb](../Fractions_Skill_Score.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on  Fractional Skill Score (FSS)](fss_thumbnail.png)

# %% [markdown]
# [Diebold_Mariano_Test_Statistic.ipynb](../Diebold_Mariano_Test_Statistic.ipynb) tutorial gallery thumbnail (below)

# %% [markdown]
# ![Thumbnail image for the tutorial on Diebold Mariano Test Statistic](diebold_mariano_thumbnail.png)
